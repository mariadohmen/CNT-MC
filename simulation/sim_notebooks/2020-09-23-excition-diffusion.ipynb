# %%
import random
import sys

import numpy as np
import matplotlib.pyplot as plt

# Bokeh imports
from bokeh.io import output_notebook, show, save
from bokeh.plotting import figure, output_file, ColumnDataSource, reset_output
from bokeh.models import HoverTool
output_notebook()

from ipywidgets.widgets import Text

#scipy constants
from scipy.constants import Boltzmann as kB
from scipy.constants import Avogadro as NA
from scipy.constants import Planck as h
from scipy.constants import speed_of_light as c0
from scipy.constants import R

sys.path.append('../CNT-SIM/')
from CNTSimFile import CNTSimFile
from mc_sim import exciton_sim_4_lvl_full_exchange, exciton_sim
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
k_er_per_s = 0.1e9
k_br_per_s = 0.1e9  # constant for radiativ decay from S11*
k_enr_per_s = 2e8 
k_bnr_per_s = 4e8   # constant for non-radiativ decay from S11*

k_de_per_s = 1e8  # constant for going from dark to S11 state
k_ed_per_s = 1e8  # constant for going from S11 to dark statestate

# termal detrapping 10.1021/acs.jpclett.8b03732
k_bd_per_s = 0.5 * (1e12 / 385 + 1e12 / 1132) + 0.1e12 * np.exp(-1.6182e-11 /
                                                                (kB * 300))

k_dnr_per_s = 2e8

kin_const_1 = np.array([k_br_per_s, k_er_per_s, k_bnr_per_s, k_enr_per_s, k_bd_per_s, k_ed_per_s,
                        k_de_per_s, k_dnr_per_s])

# %%
diff_const = np.zeros((8, 2))

# %%
diff_const[:, 0] = np.linspace(1.07e15,1.5e16, 8)
diff_const[:, 1] = np.linspace(1.07e15/3,1.5e16/3, 8)

# %%
exc_sim_diff_1 = CNTSimFile('../sim_output/2020-09-23_exciton_sim_diff_1.h5', kin_const_1)

# %%
exc_sim_diff_1.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 30, 'CNT_length': 750},
                                   plot=True)
# Out:
# Start of calculation: 2020-09-23 13:21:23.080760
# Start of exiton simulation: 2020-09-23 13:21:23.082145
# End exiton simulation: 2020-09-23 13:21:23.172306
# Elapsed time: 00:00:00
# diff constant set processed(0/ 8)
# Start of exiton simulation: 2020-09-23 13:21:23.173769
# End exiton simulation: 2020-09-23 13:29:42.629457
# Elapsed time: 00:08:19
# diff constant set processed(1/ 8)
# Start of exiton simulation: 2020-09-23 13:29:42.633978
# End exiton simulation: 2020-09-23 13:38:05.209390
# Elapsed time: 00:08:22
# diff constant set processed(2/ 8)
# Start of exiton simulation: 2020-09-23 13:38:05.213747
# End exiton simulation: 2020-09-23 13:46:33.388591
# Elapsed time: 00:08:28
# diff constant set processed(3/ 8)
# Start of exiton simulation: 2020-09-23 13:46:33.389991
# End exiton simulation: 2020-09-23 13:54:53.493976
# Elapsed time: 00:08:20
# diff constant set processed(4/ 8)
# Start of exiton simulation: 2020-09-23 13:54:53.497939
# End exiton simulation: 2020-09-23 14:03:23.053099
# Elapsed time: 00:08:29
# diff constant set processed(5/ 8)
# Start of exiton simulation: 2020-09-23 14:03:23.057671
# End exiton simulation: 2020-09-23 14:11:49.699327
# Elapsed time: 00:08:26
# diff constant set processed(6/ 8)
# Start of exiton simulation: 2020-09-23 14:11:49.703703
# End exiton simulation: 2020-09-23 14:20:20.499341
# Elapsed time: 00:08:30
# diff constant set processed(7/ 8)
# Start of exiton simulation: 2020-09-23 14:20:20.500956
# End exiton simulation: 2020-09-23 14:28:43.549115
# Elapsed time: 00:08:23
# End exiton simulation: 2020-09-23 14:28:43.553414
# Elapsed time: 01:07:20

# %%
exc_sim_diff_1.save()

# %%
exc_sim_diff_2 = CNTSimFile('../sim_output/2020-09-23_exciton_sim_diff_2.h5', kin_const_1)

# %%
diff_const[:, 0] = np.linspace(1.07e15,1e14, 8)
diff_const[:, 1] = np.linspace(1.07e15/3,1.5e16/3, 8)

# %%
exc_sim_diff_2.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 30, 'CNT_length': 750},
                                   plot=True)
# Out:
# Start of calculation: 2020-09-24 09:07:31.908503
# Start of exiton simulation: 2020-09-24 09:07:31.909353
# End exiton simulation: 2020-09-24 09:07:31.972402
# Elapsed time: 00:00:00
# diff constant set processed(0/ 8)
# Start of exiton simulation: 2020-09-24 09:07:31.974062
# End exiton simulation: 2020-09-24 09:15:40.504745
# Elapsed time: 00:08:08
# diff constant set processed(1/ 8)
# Start of exiton simulation: 2020-09-24 09:15:40.509916
# End exiton simulation: 2020-09-24 09:23:41.031357
# Elapsed time: 00:08:00
# diff constant set processed(2/ 8)
# Start of exiton simulation: 2020-09-24 09:23:41.033013
# End exiton simulation: 2020-09-24 09:31:46.797286
# Elapsed time: 00:08:05
# diff constant set processed(3/ 8)
# Start of exiton simulation: 2020-09-24 09:31:46.798582
# End exiton simulation: 2020-09-24 09:39:58.372825
# Elapsed time: 00:08:11
# diff constant set processed(4/ 8)
# Start of exiton simulation: 2020-09-24 09:39:58.378195
# End exiton simulation: 2020-09-24 09:48:03.441965
# Elapsed time: 00:08:05
# diff constant set processed(5/ 8)
# Start of exiton simulation: 2020-09-24 09:48:03.446748
# End exiton simulation: 2020-09-24 09:56:04.859734
# Elapsed time: 00:08:01
# diff constant set processed(6/ 8)
# Start of exiton simulation: 2020-09-24 09:56:04.865509
# End exiton simulation: 2020-09-24 10:03:55.676074
# Elapsed time: 00:07:50
# diff constant set processed(7/ 8)
# Start of exiton simulation: 2020-09-24 10:03:55.685302
# End exiton simulation: 2020-09-24 10:11:07.378090
# Elapsed time: 00:07:11
# End exiton simulation: 2020-09-24 10:11:07.383484
# Elapsed time: 01:03:35

# %%
exc_sim_diff_2.save()

# %%
exc_sim_diff_3 = CNTSimFile('../sim_output/2020-09-23_exciton_sim_diff_3.h5', kin_const_1)

# %%
diff_const[:, 0] = np.linspace(1.07e15,1e14, 8)
diff_const[:, 1] = np.linspace(1.07e15/3,1.5e17/3, 8)

# %%
exc_sim_diff_2.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 30, 'CNT_length': 750},
                                   plot=True)
# Out:
# Start of calculation: 2020-09-24 11:08:58.300432
# Start of exiton simulation: 2020-09-24 11:08:58.300887
# End exiton simulation: 2020-09-24 11:08:58.418175
# Elapsed time: 00:00:00
# diff constant set processed(0/ 8)
# Start of exiton simulation: 2020-09-24 11:08:58.420068
# End exiton simulation: 2020-09-24 11:17:18.721480
# Elapsed time: 00:08:20
# diff constant set processed(1/ 8)
# Start of exiton simulation: 2020-09-24 11:17:18.728133
# End exiton simulation: 2020-09-24 11:25:27.485329
# Elapsed time: 00:08:08
# diff constant set processed(2/ 8)
# Start of exiton simulation: 2020-09-24 11:25:27.486992
# End exiton simulation: 2020-09-24 11:33:43.503072
# Elapsed time: 00:08:16
# diff constant set processed(3/ 8)
# Start of exiton simulation: 2020-09-24 11:33:43.509097
# End exiton simulation: 2020-09-24 11:41:54.328033
# Elapsed time: 00:08:10
# diff constant set processed(4/ 8)
# Start of exiton simulation: 2020-09-24 11:41:54.333688
# End exiton simulation: 2020-09-24 11:49:52.045394
# Elapsed time: 00:07:57
# diff constant set processed(5/ 8)
# Start of exiton simulation: 2020-09-24 11:49:52.051343
# End exiton simulation: 2020-09-24 11:57:44.558201
# Elapsed time: 00:07:52
# diff constant set processed(6/ 8)
# Start of exiton simulation: 2020-09-24 11:57:44.563442
# End exiton simulation: 2020-09-24 12:05:31.776073
# Elapsed time: 00:07:47
# diff constant set processed(7/ 8)
# Start of exiton simulation: 2020-09-24 12:05:31.777526
# End exiton simulation: 2020-09-24 12:12:54.930323
# Elapsed time: 00:07:23
# End exiton simulation: 2020-09-24 12:12:54.935953
# Elapsed time: 01:03:56

# %%
exc_sim_diff_2.save()
