# %%
import sys

import numpy as np
import matplotlib.pyplot as plt

sys.path.append('../CNT-SIM/')
from CNTSimFile import CNTSimFile
from mc_sim import exciton_sim

#scipy constants
from scipy.constants import Boltzmann as kB

k_er_per_s = 1e8
k_br_per_s = 1e8  # constant for radiativ decay from S11*
k_enr_per_s = 2e8 
k_bnr_per_s = 4e8   # constant for non-radiativ decay from S11*

k_de_per_s = 1e8  # constant for going from dark to S11 state
k_ed_per_s = 1e8  # constant for going from S11 to dark statestate

# termal detrapping 10.1021/acs.jpclett.8b03732
k_bd_per_s = 0.5 * (1e12 / 385 + 1e12 / 1132) + 0.1e12 * np.exp(-1.6182e-11 /
                                                                (kB * 300))

k_dnr_per_s = 2e8

####
# lower D_e and raise D_d
###

kin_const_1 = np.array([k_br_per_s, k_er_per_s, k_bnr_per_s, k_enr_per_s, k_bd_per_s, k_ed_per_s,
                        k_de_per_s, k_dnr_per_s])

exc_sim_diff_1 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-diff-const_prist_1.h5', kin_const_1)

diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15,1.5e16, 10)
diff_const[:, 1] = np.linspace(1.07e15/3,1.5e16/3, 10)


exc_sim_diff_1.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 0, 'CNT_length': 750})
exc_sim_diff_1.save()



exc_sim_diff_2 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-diff-const_defected_2.h5', kin_const_1)


exc_sim_diff_2.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 30, 'CNT_length': 750})

exc_sim_diff_2.save()



exc_sim_diff_3 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-diff-const_prist_3.h5', kin_const_1)

diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15,1.5e16, 10)
diff_const[:, 1] = np.linspace(1.07e15/3,1.5e18/3, 10)

exc_sim_diff_3.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 0, 'CNT_length': 750})

exc_sim_diff_3.save()



exc_sim_diff_4 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-diff-const_defected_4.h5', kin_const_1)


exc_sim_diff_4.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 30, 'CNT_length': 750})


exc_sim_diff_4.save()


exc_sim_diff_5 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-diff-const_prist_5.h5', kin_const_1)

diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15,1.5e18, 10)
diff_const[:, 1] = np.linspace(1.07e15/3,1.5e16/3, 10)

exc_sim_diff_5.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 0, 'CNT_length': 750})


exc_sim_diff_5.save()



exc_sim_diff_6 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-diff-const_defected_6.h5', kin_const_1)


exc_sim_diff_6.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 30, 'CNT_length': 750})


exc_sim_diff_6.save()
# Out:
# ../CNT-SIM/CNTSimFile.py:31: UserWarning: File already exists, kinetic constants ingored.
#   warn("File already exists, kinetic constants ingored.")
# Existing file loaded successfully.
# Start of calculation: 2020-09-28 12:46:12.002270
# Start of exiton simulation: 2020-09-28 12:46:12.002837
# End exiton simulation: 2020-09-28 12:46:12.005183
# Elapsed time: 00:00:00
# diff constant set processed(0/ 10)
# Start of exiton simulation: 2020-09-28 12:46:12.006394
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c0e351dfefc6> in <module>
#      40
#      41 exc_sim_diff_1.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
# ---> 42                                                                      'n_defects': 0, 'CNT_length': 750})
#      43 exc_sim_diff_1.save()
#      44
#
# ~/projects/CNT-MC/simulation/CNT-SIM/CNTSimFile.py in diffusion_dependence(self, n_photons, func, diff_const, func_kwargs, plot)
#     329                     {'Diff_exc_e': diff_const[i, 0],
#     330                      'Diff_exc_d': diff_const[i, 1],
# --> 331                      **func_kwargs})
#     332         end = time.time()
#     333         elapsed = end - start
#
# ~/projects/CNT-MC/simulation/CNT-SIM/CNTSimFile.py in photons_fate(self, n_photons, func, rate_const, func_kwargs)
#     137         # loop for the desired number of photons
#     138         for p in np.arange(n_photons-1):
# --> 139             photons_fate += func(rate_const=rate_const, **func_kwargs)
#     140             if self.notebook_output is True:
#     141                 info.value = f"Processing photon ({p+2}/ {n_photons})"
#
# ~/projects/CNT-MC/simulation/CNT-SIM/mc_sim.py in exciton_sim(t_step, rate_const, Diff_exc_e, Diff_exc_d, n_defects, CNT_length, r_exc_nm, alpha)
#     412     # Masks defects which are too close together and result in non-radiative
#     413     # decay
# --> 414     defects = np.sort(defects)
#     415     if len(defects) > 2:
#     416         mask = [defects[1]-defects[0] >= r_exc_nm]
#
# <__array_function__ internals> in sort(*args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sort(a, axis, kind, order)
#     835
#     836
# --> 837 @array_function_dispatch(_sort_dispatcher)
#     838 def sort(a, axis=-1, kind=None, order=None):
#     839     """
#
# KeyboardInterrupt:
