# %%
import sys

import numpy as np
import matplotlib.pyplot as plt

sys.path.append('../CNT-SIM/')
from CNTSimFile import CNTSimFile
from mc_sim import exciton_sim

#scipy constants
from scipy.constants import Boltzmann as kB

k_er_per_s = 1e8
k_br_per_s = 1e8  # constant for radiativ decay from S11*
k_enr_per_s = 2e8 
k_bnr_per_s = 4e8   # constant for non-radiativ decay from S11*

k_de_per_s = 1e8  # constant for going from dark to S11 state
k_ed_per_s = 1e8  # constant for going from S11 to dark statestate

# termal detrapping 10.1021/acs.jpclett.8b03732
k_bd_per_s = 0.5 * (1e12 / 385 + 1e12 / 1132) + 0.1e12 * np.exp(-1.6182e-11 /
                                                                (kB * 300))

k_dnr_per_s = 2e8

####
# raise k_er; raise k_dnr/k_enr
###
kin_const_1 = np.array([k_br_per_s, k_er_per_s, k_bnr_per_s, k_enr_per_s, k_bd_per_s, k_ed_per_s,
                        k_de_per_s, k_dnr_per_s])

exc_sim_rk_1 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_prist_1.h5', kin_const_1)

constants_array = np.zeros((10, 3))
constants_array[:, 0] = np.linspace(1e8, 1e9, 10)
constants_array[:, 1] = np.linspace(2e8, 2e9, 10)
constants_array[:, 2] = np.linspace(2e8, 2e9, 10)

exc_sim_rk_1.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_dnr', 'k_enr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})

exc_sim_rk_1.save()



exc_sim_rk_2 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_defected_2.h5', kin_const_1)


exc_sim_rk_2.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_dnr', 'k_enr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 30, 'CNT_length': 750})

exc_sim_rk_2.save()



exc_sim_rk_3 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_prist_3.h5', kin_const_1)

constants_array = np.zeros((10, 3))
constants_array[:, 0] = np.linspace(1e8, 1e9, 10)
constants_array[:, 1] = np.linspace(2e8, 2e10, 10)
constants_array[:, 2] = np.linspace(2e8, 2e10, 10)

exc_sim_rk_3.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_dnr', 'k_enr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})

exc_sim_rk_3.save()



exc_sim_rk_4 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_defected_4.h5', kin_const_1)


exc_sim_rk_4.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_dnr', 'k_enr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 30, 'CNT_length': 750})

exc_sim_rk_4.save()


exc_sim_rk_5 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_prist_5.h5', kin_const_1)

constants_array = np.zeros((10, 3))
constants_array[:, 0] = np.linspace(1e8, 1e10, 10)
constants_array[:, 1] = np.linspace(2e8, 2e9, 10)
constants_array[:, 2] = np.linspace(2e8, 2e9, 10)

exc_sim_rk_5.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_dnr', 'k_enr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})

exc_sim_rk_5.save()



exc_sim_rk_6 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_defected_6.h5', kin_const_1)


exc_sim_rk_6.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_dnr', 'k_enr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 30, 'CNT_length': 750})

exc_sim_rk_6.save()
# Out:
# ../CNT-SIM/CNTSimFile.py:31: UserWarning: File already exists, kinetic constants ingored.
#   warn("File already exists, kinetic constants ingored.")
# Existing file loaded successfully.
# Start of calculation: 2020-09-26 18:36:29.899348
# Start of exiton simulation: 2020-09-26 18:36:29.899560
# End exiton simulation: 2020-09-26 18:36:39.983050
# Elapsed time: 00:00:10
# rate constant set processed((0/ 10))
# Start of exiton simulation: 2020-09-26 18:36:39.984526
# End exiton simulation: 2020-09-26 18:36:49.496999
# Elapsed time: 00:00:09
# rate constant set processed((1/ 10))
# Start of exiton simulation: 2020-09-26 18:36:49.499429
# End exiton simulation: 2020-09-26 18:36:59.106017
# Elapsed time: 00:00:09
# rate constant set processed((2/ 10))
# Start of exiton simulation: 2020-09-26 18:36:59.111871
# End exiton simulation: 2020-09-26 18:37:08.738348
# Elapsed time: 00:00:09
# rate constant set processed((3/ 10))
# Start of exiton simulation: 2020-09-26 18:37:08.740383
# ...

# %%
import sys

import numpy as np
import matplotlib.pyplot as plt

sys.path.append('../CNT-SIM/')
from CNTSimFile import CNTSimFile
from mc_sim import exciton_sim

#scipy constants
from scipy.constants import Boltzmann as kB

k_er_per_s = 1e8
k_br_per_s = 1e8  # constant for radiativ decay from S11*
k_enr_per_s = 2e8 
k_bnr_per_s = 4e8   # constant for non-radiativ decay from S11*

k_de_per_s = 1e8  # constant for going from dark to S11 state
k_ed_per_s = 1e8  # constant for going from S11 to dark statestate

# termal detrapping 10.1021/acs.jpclett.8b03732
k_bd_per_s = 0.5 * (1e12 / 385 + 1e12 / 1132) + 0.1e12 * np.exp(-1.6182e-11 /
                                                                (kB * 300))

k_dnr_per_s = 2e8

####
# raise k_er; lower k_de
###
kin_const_1 = np.array([k_br_per_s, k_er_per_s, k_bnr_per_s, k_enr_per_s, k_bd_per_s, k_ed_per_s,
                        k_de_per_s, k_dnr_per_s])

exc_sim_rk_7 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_prist_7.h5', kin_const_1)

constants_array = np.zeros((10, 2))

constants_array[:, 0] = np.linspace(1e8, 1e9, 10)
constants_array[:, 1] = np.linspace(1e8, 1e9, 10)

exc_sim_rk_7.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_de'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})

exc_sim_rk_7.save()



exc_sim_rk_8 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_defected_8.h5', kin_const_1)


exc_sim_rk_8.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_de'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 30, 'CNT_length': 750})

exc_sim_rk_8.save()



exc_sim_rk_9 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_prist_9.h5', kin_const_1)

constants_array = np.zeros((10, 2))

constants_array[:, 0] = np.linspace(1e8, 1e9, 10)
constants_array[:, 1] = np.linspace(1e8, 1e10, 10)

exc_sim_rk_9.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_de'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})

exc_sim_rk_9.save()



exc_sim_rk_10 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_defected_10.h5', kin_const_1)


exc_sim_rk_10.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_de'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 30, 'CNT_length': 750})

exc_sim_rk_10.save()


exc_sim_rk_11 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_prist_11.h5', kin_const_1)

constants_array = np.zeros((10, 2))

constants_array[:, 0] = np.linspace(1e8, 1e10, 10)
constants_array[:, 1] = np.linspace(1e8, 1e9, 10)

exc_sim_rk_11.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_de'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})

exc_sim_rk_11.save()



exc_sim_rk_12 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_defected_12.h5', kin_const_1)


exc_sim_rk_12.rate_const_dependence(10000, exciton_sim, constants_array, ['k_er', 'k_de'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 30, 'CNT_length': 750})

exc_sim_rk_12.save()
# Out:
# Start of calculation: 2020-09-26 09:26:31.258326
# Start of exiton simulation: 2020-09-26 09:26:31.258608
# End exiton simulation: 2020-09-26 09:26:41.021456
# Elapsed time: 00:00:09
# rate constant set processed((0/ 10))
# Start of exiton simulation: 2020-09-26 09:26:41.023686
# End exiton simulation: 2020-09-26 09:26:50.736250
# Elapsed time: 00:00:09
# rate constant set processed((1/ 10))
# Start of exiton simulation: 2020-09-26 09:26:50.737602
# End exiton simulation: 2020-09-26 09:27:00.539047
# Elapsed time: 00:00:09
# rate constant set processed((2/ 10))
# Start of exiton simulation: 2020-09-26 09:27:00.541595
# End exiton simulation: 2020-09-26 09:27:10.418860
# Elapsed time: 00:00:09
# rate constant set processed((3/ 10))
# Start of exiton simulation: 2020-09-26 09:27:10.419428
# End exiton simulation: 2020-09-26 09:27:20.213757
# Elapsed time: 00:00:09
# rate constant set processed((4/ 10))
# Start of exiton simulation: 2020-09-26 09:27:20.215874
# ...

# %%
import sys

import numpy as np
import matplotlib.pyplot as plt

sys.path.append('../CNT-SIM/')
from CNTSimFile import CNTSimFile
from mc_sim import exciton_sim

#scipy constants
from scipy.constants import Boltzmann as kB

k_er_per_s = 1e8
k_br_per_s = 1e8  # constant for radiativ decay from S11*
k_enr_per_s = 2e8 
k_bnr_per_s = 4e8   # constant for non-radiativ decay from S11*

k_de_per_s = 1e8  # constant for going from dark to S11 state
k_ed_per_s = 1e8  # constant for going from S11 to dark statestate

# termal detrapping 10.1021/acs.jpclett.8b03732
k_bd_per_s = 0.5 * (1e12 / 385 + 1e12 / 1132) + 0.1e12 * np.exp(-1.6182e-11 /
                                                                (kB * 300))

k_dnr_per_s = 2e8

####
# Diff lower De and raise Dd
###

kin_const_1 = np.array([k_br_per_s, k_er_per_s, k_bnr_per_s, k_enr_per_s, k_bd_per_s, k_ed_per_s,
                        k_de_per_s, k_dnr_per_s])

exc_sim_diff_1 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_prist_1.h5', kin_const_1)

diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15,1.5e16, 10)
diff_const[:, 1] = np.linspace(1.07e15/3,1.5e16/3, 10)


exc_sim_diff_1.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 0, 'CNT_length': 750})
exc_sim_diff_1.save()



exc_sim_diff_2 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_defected_2.h5', kin_const_1)


exc_sim_diff_2.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 30, 'CNT_length': 750})

exc_sim_diff_2.save()



exc_sim_diff_3 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_prist_3.h5', kin_const_1)

diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15,1.5e16, 10)
diff_const[:, 1] = np.linspace(1.07e15/3,1.5e18/3, 10)

exc_sim_diff_3.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 0, 'CNT_length': 750})

exc_sim_diff_3.save()



exc_sim_diff_4 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_defected_4.h5', kin_const_1)


exc_sim_diff_4.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 30, 'CNT_length': 750})


exc_sim_diff_4.save()


exc_sim_diff_5 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_prist_5.h5', kin_const_1)

diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15,1.5e18, 10)
diff_const[:, 1] = np.linspace(1.07e15/3,1.5e16/3, 10)

exc_sim_diff_5.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 0, 'CNT_length': 750})


exc_sim_diff_5.save()



exc_sim_diff_6 = CNTSimFile('../sim_output/2020-09-25-exciton_sim-rate-const_defected_6.h5', kin_const_1)


exc_sim_diff_6.diffusion_dependence(10000, exciton_sim, diff_const, {'t_step': 1, 'r_exc_nm': 2,
                                                                     'n_defects': 30, 'CNT_length': 750})


exc_sim_diff_6.save()
