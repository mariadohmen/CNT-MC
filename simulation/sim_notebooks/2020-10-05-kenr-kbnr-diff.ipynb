# %%
import random
import sys

import numpy as np
import matplotlib.pyplot as plt
from itertools import compress

# Bokeh imports
from bokeh.io import output_notebook, show, save
from bokeh.plotting import figure, output_file, ColumnDataSource, reset_output
from bokeh.models import HoverTool
output_notebook()

from ipywidgets.widgets import Text

#scipy constants
from scipy.constants import Boltzmann as kB
from scipy.constants import Avogadro as NA
from scipy.constants import Planck as h
from scipy.constants import speed_of_light as c0
from scipy.constants import R

sys.path.append('../CNT-SIM/')
from CNTSimFile import CNTSimFile
from mc_sim import exciton_sim
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
k_er_per_s = 1e8
k_br_per_s = 1e8  # constant for radiativ decay from S11*
k_enr_per_s = 2e8 
k_bnr_per_s = 4e8   # constant for non-radiativ decay from S11*

k_de_per_s = 1e8  # constant for going from dark to S11 state
k_ed_per_s = 1e8  # constant for going from S11 to dark statestate

# termal detrapping 10.1021/acs.jpclett.8b03732
k_bd_per_s = 0.5 * (1e12 / 385 + 1e12 / 1132) + 0.1e12 * np.exp(-1.6182e-11 /
                                                                (kB * 300))
k_dnr_per_s = 2e8

kin_const_1 = np.array([k_br_per_s, k_er_per_s, k_bnr_per_s, k_enr_per_s, k_bd_per_s, k_ed_per_s,
                        k_de_per_s, k_dnr_per_s])

# %%
exc_sim_ker_kbnr_diff_1 = CNTSimFile('../sim_output/2020-10-05-exciton_sim-kenr_kbnr_diff_prist_3.h5', kin_const_1)

# %%
diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15, 1.07e16, 10)
diff_const[:, 1] = np.linspace(1.07e15/3, 1.07e16/3, 10)

constants_array = np.zeros((10, 2))
constants_array[:, 0] = np.linspace(2e8, 1e7, 10)
constants_array[:, 1] = np.linspace(4e8, 4e9, 10)

# %%
exc_sim_ker_kbnr_diff_1.parameter_dependence(100000, exciton_sim, constants_array, ['k_enr', 'k_bnr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                    diff_const, (1.07e15, 1.07e15/3),
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})
exc_sim_ker_kbnr_diff_1.save()
# Out:
# Start of calculation: 2020-10-05 14:58:39.308464
# Start of exiton simulation: 2020-10-05 14:58:39.310047
# End exiton simulation: 2020-10-05 15:00:16.698568
# Elapsed time: 00:01:37
# rate constant set processed(1/ 10)
# Start of exiton simulation: 2020-10-05 15:00:16.703898
# End exiton simulation: 2020-10-05 15:02:10.053752
# Elapsed time: 00:01:53
# rate constant set processed(2/ 10)
# Start of exiton simulation: 2020-10-05 15:02:10.055148
# End exiton simulation: 2020-10-05 15:03:36.401117
# Elapsed time: 00:01:26
# rate constant set processed(3/ 10)
# Start of exiton simulation: 2020-10-05 15:03:36.407449
# End exiton simulation: 2020-10-05 15:04:51.107213
# Elapsed time: 00:01:14
# rate constant set processed(4/ 10)
# Start of exiton simulation: 2020-10-05 15:04:51.112626
# End exiton simulation: 2020-10-05 15:05:58.252170
# Elapsed time: 00:01:07
# rate constant set processed(5/ 10)
# Start of exiton simulation: 2020-10-05 15:05:58.256893
# End exiton simulation: 2020-10-05 15:07:01.240411
# Elapsed time: 00:01:02
# rate constant set processed(6/ 10)
# Start of exiton simulation: 2020-10-05 15:07:01.241924
# End exiton simulation: 2020-10-05 15:08:01.134584
# Elapsed time: 00:00:59
# rate constant set processed(7/ 10)
# Start of exiton simulation: 2020-10-05 15:08:01.138576
# End exiton simulation: 2020-10-05 15:08:56.311818
# Elapsed time: 00:00:55
# rate constant set processed(8/ 10)
# Start of exiton simulation: 2020-10-05 15:08:56.313304
# End exiton simulation: 2020-10-05 15:09:49.050578
# Elapsed time: 00:00:52
# rate constant set processed(9/ 10)
# Start of exiton simulation: 2020-10-05 15:09:49.053214
# End exiton simulation: 2020-10-05 15:10:38.818295
# Elapsed time: 00:00:49
# rate constant set processed(10/ 10)
# Start of exiton simulation: 2020-10-05 15:10:38.822755
# End exiton simulation: 2020-10-05 15:11:26.563484
# Elapsed time: 00:00:47
# End exiton simulation: 2020-10-05 15:11:26.576326
# Elapsed time: 00:12:47
# ../CNT-SIM/CNTSimFile.py:574: RuntimeWarning: invalid value encountered in true_divide
#   self.QY_delta = (self.QY - self.QY_ref) / self.QY_ref

# %%
exc_sim_ker_kbnr_diff_1 = CNTSimFile('../sim_output/2020-10-06-exciton_sim-kenr_kbnr_diff_4.h5', kin_const_1)

# %%
exc_sim_ker_kbnr_diff_1.parameter_dependence(10000, exciton_sim, constants_array, ['k_enr', 'k_bnr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                    diff_const, (1.07e15, 1.07e15/3),
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 30, 'CNT_length': 750})
exc_sim_ker_kbnr_diff_1.save()
# Out:
# Start of calculation: 2020-10-06 11:36:08.200806
# Start of exiton simulation: 2020-10-06 11:36:08.201877
# End exiton simulation: 2020-10-06 11:44:31.178589
# Elapsed time: 00:08:22
# rate constant set processed(1/ 10)
# Start of exiton simulation: 2020-10-06 11:44:31.187782
# End exiton simulation: 2020-10-06 11:53:37.517712
# Elapsed time: 00:09:06
# rate constant set processed(2/ 10)
# Start of exiton simulation: 2020-10-06 11:53:37.522451
# End exiton simulation: 2020-10-06 12:03:10.974255
# Elapsed time: 00:09:33
# rate constant set processed(3/ 10)
# Start of exiton simulation: 2020-10-06 12:03:10.978627
# End exiton simulation: 2020-10-06 12:12:48.039316
# Elapsed time: 00:09:37
# rate constant set processed(4/ 10)
# Start of exiton simulation: 2020-10-06 12:12:48.044280
# End exiton simulation: 2020-10-06 12:22:21.076019
# Elapsed time: 00:09:33
# rate constant set processed(5/ 10)
# Start of exiton simulation: 2020-10-06 12:22:21.080436
# End exiton simulation: 2020-10-06 12:31:47.751832
# Elapsed time: 00:09:26
# rate constant set processed(6/ 10)
# Start of exiton simulation: 2020-10-06 12:31:47.753355
# End exiton simulation: 2020-10-06 12:41:16.493538
# Elapsed time: 00:09:28
# rate constant set processed(7/ 10)
# Start of exiton simulation: 2020-10-06 12:41:16.497388
# End exiton simulation: 2020-10-06 12:50:28.868677
# Elapsed time: 00:09:12
# rate constant set processed(8/ 10)
# Start of exiton simulation: 2020-10-06 12:50:28.877495
# End exiton simulation: 2020-10-06 12:59:46.842533
# Elapsed time: 00:09:17
# rate constant set processed(9/ 10)
# Start of exiton simulation: 2020-10-06 12:59:46.844281
# End exiton simulation: 2020-10-06 13:17:52.942836
# Elapsed time: 00:09:01
# End exiton simulation: 2020-10-06 13:17:52.947278
# Elapsed time: 01:41:44

# %%
diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15, 1.07e15 * 2, 10)
diff_const[:, 1] = np.linspace(1.07e15/3, 1.07e15/3 * 2, 10)

constants_array = np.zeros((10, 2))
constants_array[:, 0] = np.linspace(2e8, 2e8 / 2, 10)
constants_array[:, 1] = np.linspace(4e8, 4e8 / 2, 10)

# %%
exc_sim_ker_kbnr_diff_1 = CNTSimFile('../sim_output/2020-10-05-exciton_sim-kenr_kbnr_diff_prist_5.h5', kin_const_1)

# %%
exc_sim_ker_kbnr_diff_1.parameter_dependence(100000, exciton_sim, constants_array, ['k_enr', 'k_bnr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                    diff_const, (1.07e15, 1.07e15/3),
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})
exc_sim_ker_kbnr_diff_1.save()
# Out:
# Start of calculation: 2020-10-06 17:38:54.713252
# Start of exiton simulation: 2020-10-06 17:38:54.714010
# End exiton simulation: 2020-10-06 17:40:38.182318
# Elapsed time: 00:01:43
# rate constant set processed(1/ 10)
# Start of exiton simulation: 2020-10-06 17:40:38.184690
# End exiton simulation: 2020-10-06 17:42:35.250561
# Elapsed time: 00:01:57
# rate constant set processed(2/ 10)
# Start of exiton simulation: 2020-10-06 17:42:35.252366
# End exiton simulation: 2020-10-06 17:44:29.062746
# Elapsed time: 00:01:53
# rate constant set processed(3/ 10)
# Start of exiton simulation: 2020-10-06 17:44:29.067991
# End exiton simulation: 2020-10-06 17:46:16.905787
# Elapsed time: 00:01:47
# rate constant set processed(4/ 10)
# Start of exiton simulation: 2020-10-06 17:46:16.915607
# End exiton simulation: 2020-10-06 17:48:02.797822
# Elapsed time: 00:01:45
# rate constant set processed(5/ 10)
# Start of exiton simulation: 2020-10-06 17:48:02.803184
# End exiton simulation: 2020-10-06 17:49:43.719947
# Elapsed time: 00:01:40
# rate constant set processed(6/ 10)
# Start of exiton simulation: 2020-10-06 17:49:43.725231
# End exiton simulation: 2020-10-06 17:51:21.983527
# Elapsed time: 00:01:38
# rate constant set processed(7/ 10)
# Start of exiton simulation: 2020-10-06 17:51:21.988169
# End exiton simulation: 2020-10-06 17:52:58.559749
# Elapsed time: 00:01:36
# rate constant set processed(8/ 10)
# Start of exiton simulation: 2020-10-06 17:52:58.566001
# End exiton simulation: 2020-10-06 17:54:31.604103
# Elapsed time: 00:01:33
# rate constant set processed(9/ 10)
# Start of exiton simulation: 2020-10-06 17:54:31.605844
# End exiton simulation: 2020-10-06 17:56:00.932154
# Elapsed time: 00:01:29
# rate constant set processed(10/ 10)
# Start of exiton simulation: 2020-10-06 17:56:00.935815
# End exiton simulation: 2020-10-06 17:57:29.968742
# Elapsed time: 00:01:29
# End exiton simulation: 2020-10-06 17:57:29.992523
# Elapsed time: 00:18:35
# ../CNT-SIM/CNTSimFile.py:574: RuntimeWarning: invalid value encountered in true_divide
#   self.QY_delta = (self.QY - self.QY_ref) / self.QY_ref

# %%
exc_sim_ker_kbnr_diff_1 = CNTSimFile('../sim_output/2020-10-05-exciton_sim-kenr_kbnr_diff_defect_6.h5', kin_const_1)

# %%
exc_sim_ker_kbnr_diff_1.parameter_dependence(10000, exciton_sim, constants_array, ['k_enr', 'k_bnr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                    diff_const, (1.07e15, 1.07e15/3),
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 30, 'CNT_length': 750})
exc_sim_ker_kbnr_diff_1.save()
# Out:
# Start of calculation: 2020-10-06 18:03:02.028931
# Start of exiton simulation: 2020-10-06 18:03:02.030846
# End exiton simulation: 2020-10-06 18:11:45.950742
# Elapsed time: 00:08:43
# rate constant set processed(1/ 10)
# Start of exiton simulation: 2020-10-06 18:11:45.952899
# End exiton simulation: 2020-10-06 18:20:51.057637
# Elapsed time: 00:09:05
# rate constant set processed(2/ 10)
# Start of exiton simulation: 2020-10-06 18:20:51.063259
# End exiton simulation: 2020-10-06 18:30:06.310783
# Elapsed time: 00:09:15
# rate constant set processed(3/ 10)
# Start of exiton simulation: 2020-10-06 18:30:06.315467
# End exiton simulation: 2020-10-06 18:39:16.272143
# Elapsed time: 00:09:09
# rate constant set processed(4/ 10)
# Start of exiton simulation: 2020-10-06 18:39:16.279592
# End exiton simulation: 2020-10-06 18:48:36.544332
# Elapsed time: 00:09:20
# rate constant set processed(5/ 10)
# Start of exiton simulation: 2020-10-06 18:48:36.548101
# End exiton simulation: 2020-10-06 18:57:50.673515
# Elapsed time: 00:09:14
# rate constant set processed(6/ 10)
# Start of exiton simulation: 2020-10-06 18:57:50.678097
# End exiton simulation: 2020-10-06 19:07:15.033399
# Elapsed time: 00:09:24
# rate constant set processed(7/ 10)
# Start of exiton simulation: 2020-10-06 19:07:15.034703
# End exiton simulation: 2020-10-06 19:16:31.667256
# Elapsed time: 00:09:16
# rate constant set processed(8/ 10)
# Start of exiton simulation: 2020-10-06 19:16:31.672110
# End exiton simulation: 2020-10-06 19:25:44.021127
# Elapsed time: 00:09:12
# rate constant set processed(9/ 10)
# Start of exiton simulation: 2020-10-06 19:25:44.022645
# End exiton simulation: 2020-10-06 19:35:04.845066
# Elapsed time: 00:09:20
# rate constant set processed(10/ 10)
# Start of exiton simulation: 2020-10-06 19:35:04.848215
