# %%
# %load quick_imports.txt
import random
import sys
import os

import numpy as np
import matplotlib.pyplot as plt
from itertools import compress

# Bokeh imports
from bokeh.io import output_notebook, show, save
from bokeh.plotting import figure, output_file, ColumnDataSource, reset_output
from bokeh.models import HoverTool
output_notebook()

from ipywidgets.widgets import Text

#scipy constants
from scipy.constants import Boltzmann as kB
from scipy.constants import Avogadro as NA
from scipy.constants import Planck as h
from scipy.constants import speed_of_light as c0
from scipy.constants import R

sys.path.append('../CNT-SIM/')
from CNTSimFile import CNTSimFile
from mc_sim import exciton_sim

k_er_per_s = 1e8
k_br_per_s = 1e8  # constant for radiativ decay from S11*
k_enr_per_s = 2e8 
k_bnr_per_s = 4e8   # constant for non-radiativ decay from S11*

k_de_per_s = 1e8  # constant for going from dark to S11 state
k_ed_per_s = 1e8  # constant for going from S11 to dark statestate

# termal detrapping 10.1021/acs.jpclett.8b03732
k_bd_per_s = 0.5 * (1e12 / 385 + 1e12 / 1132) + 0.1e12 * np.exp(-1.6182e-11 /
                                                                (kB * 300))
k_dnr_per_s = 2e8

kin_const_1 = np.array([k_br_per_s, k_er_per_s, k_bnr_per_s, k_enr_per_s, k_bd_per_s, k_ed_per_s,
                        k_de_per_s, k_dnr_per_s])
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15, 1.07e15 * 2, 10)
diff_const[:, 1] = np.linspace(1.07e15/3, 1.07e15/3 * 2, 10)

constants_array = np.zeros((10, 2))
constants_array[:, 0] = np.linspace(4e8, 4e9, 10)
constants_array[:, 1] = np.linspace(2e8, 2e7, 10)

# %%
exc_sim_kenr_kbnr_diff_1 = CNTSimFile('../sim_output/2020-10-07-exciton_sim-kenr_kbnr_diff_prist_7.h5', kin_const_1)
# Out:
# Existing file loaded successfully.

# %%
exc_sim_kenr_kbnr_diff_1.parameter_dependence(100000, exciton_sim, constants_array, ['k_bnr', 'k_enr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                    diff_const, (1.07e15, 1.07e15/3),
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})
exc_sim_kenr_kbnr_diff_1.save()
# Out:
# Start of calculation: 2020-10-07 18:02:54.945890
# Start of exiton simulation: 2020-10-07 18:02:54.946737
# End exiton simulation: 2020-10-07 18:04:35.669801
# Elapsed time: 00:01:40
# rate constant set processed(1/ 10)
# Start of exiton simulation: 2020-10-07 18:04:35.675199
# End exiton simulation: 2020-10-07 18:06:28.159145
# Elapsed time: 00:01:52
# rate constant set processed(2/ 10)
# Start of exiton simulation: 2020-10-07 18:06:28.160522
# End exiton simulation: 2020-10-07 18:08:19.470753
# Elapsed time: 00:01:51
# rate constant set processed(3/ 10)
# Start of exiton simulation: 2020-10-07 18:08:19.475162
# End exiton simulation: 2020-10-07 18:10:04.070064
# Elapsed time: 00:01:44
# rate constant set processed(4/ 10)
# Start of exiton simulation: 2020-10-07 18:10:04.075509
# End exiton simulation: 2020-10-07 18:11:46.045865
# Elapsed time: 00:01:41
# rate constant set processed(5/ 10)
# Start of exiton simulation: 2020-10-07 18:11:46.050184
# End exiton simulation: 2020-10-07 18:13:26.544669
# Elapsed time: 00:01:40
# rate constant set processed(6/ 10)
# Start of exiton simulation: 2020-10-07 18:13:26.549429
# End exiton simulation: 2020-10-07 18:15:04.431059
# Elapsed time: 00:01:37
# rate constant set processed(7/ 10)
# Start of exiton simulation: 2020-10-07 18:15:04.435693
# End exiton simulation: 2020-10-07 18:16:38.706541
# Elapsed time: 00:01:34
# rate constant set processed(8/ 10)
# Start of exiton simulation: 2020-10-07 18:16:38.711842
# End exiton simulation: 2020-10-07 18:18:09.109660
# Elapsed time: 00:01:30
# rate constant set processed(9/ 10)
# Start of exiton simulation: 2020-10-07 18:18:09.115107
# End exiton simulation: 2020-10-07 18:19:37.269909
# Elapsed time: 00:01:28
# rate constant set processed(10/ 10)
# Start of exiton simulation: 2020-10-07 18:19:37.272191
# End exiton simulation: 2020-10-07 18:21:04.158567
# Elapsed time: 00:01:26
# End exiton simulation: 2020-10-07 18:21:04.163262
# Elapsed time: 00:18:09

# %%
diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15, 1.07e15 * 2, 10)
diff_const[:, 1] = np.linspace(1.07e15/3, 1.07e15/3 * 2, 10)

constants_array = np.zeros((10, 2))
constants_array[:, 0] = np.linspace(4e8, 4e8*2, 10)
constants_array[:, 1] = np.linspace(2e8, 2e8 / 2, 10)

# %%
exc_sim_kenr_kbnr_diff_1 = CNTSimFile('../sim_output/2020-10-08-exciton_sim-kenr_kbnr_diff_prist_9.h5', kin_const_1)

# %%
exc_sim_kenr_kbnr_diff_1.parameter_dependence(100000, exciton_sim, constants_array, ['k_bnr', 'k_enr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                    diff_const, (1.07e15, 1.07e15/3),
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})
exc_sim_kenr_kbnr_diff_1.save()
# Out:
# Start of calculation: 2020-10-08 08:43:19.555642
# Start of exiton simulation: 2020-10-08 08:43:19.555851
# End exiton simulation: 2020-10-08 08:44:56.775512
# Elapsed time: 00:01:37
# rate constant set processed(1/ 10)
# Start of exiton simulation: 2020-10-08 08:44:56.782406
# End exiton simulation: 2020-10-08 08:46:52.312175
# Elapsed time: 00:01:55
# rate constant set processed(2/ 10)
# Start of exiton simulation: 2020-10-08 08:46:52.318783
# End exiton simulation: 2020-10-08 08:48:43.266711
# Elapsed time: 00:01:50
# rate constant set processed(3/ 10)
# Start of exiton simulation: 2020-10-08 08:48:43.269280
# End exiton simulation: 2020-10-08 08:50:28.382030
# Elapsed time: 00:01:45
# rate constant set processed(4/ 10)
# Start of exiton simulation: 2020-10-08 08:50:28.390726
# End exiton simulation: 2020-10-08 08:52:10.241606
# Elapsed time: 00:01:41
# rate constant set processed(5/ 10)
# Start of exiton simulation: 2020-10-08 08:52:10.247167
# End exiton simulation: 2020-10-08 08:53:50.210145
# Elapsed time: 00:01:39
# rate constant set processed(6/ 10)
# Start of exiton simulation: 2020-10-08 08:53:50.214000
# End exiton simulation: 2020-10-08 08:55:27.201709
# Elapsed time: 00:01:36
# rate constant set processed(7/ 10)
# Start of exiton simulation: 2020-10-08 08:55:27.207632
# End exiton simulation: 2020-10-08 08:57:02.867831
# Elapsed time: 00:01:35
# rate constant set processed(8/ 10)
# Start of exiton simulation: 2020-10-08 08:57:02.875840
# End exiton simulation: 2020-10-08 08:58:33.163512
# Elapsed time: 00:01:30
# rate constant set processed(9/ 10)
# Start of exiton simulation: 2020-10-08 08:58:33.169202
# End exiton simulation: 2020-10-08 09:00:02.644337
# Elapsed time: 00:01:29
# rate constant set processed(10/ 10)
# Start of exiton simulation: 2020-10-08 09:00:02.649316
# End exiton simulation: 2020-10-08 09:01:29.850521
# Elapsed time: 00:01:27
# ../CNT-SIM/CNTSimFile.py:574: RuntimeWarning: invalid value encountered in true_divide
#   self.QY_delta = (self.QY - self.QY_ref) / self.QY_ref
# End exiton simulation: 2020-10-08 09:01:30.085407
# Elapsed time: 00:18:10

# %%
diff_const = np.zeros((10, 2))
diff_const[:, 0] = np.linspace(1.07e15, 1.07e15 * 2, 10)
diff_const[:, 1] = np.linspace(1.07e15/3, 1.07e15/3 * 2, 10)

constants_array = np.zeros((10, 2))
constants_array[:, 0] = np.linspace(4e8, 4e8*3, 10)
constants_array[:, 1] = np.linspace(2e8, 2e8 / 2, 10)

# %%
exc_sim_kenr_kbnr_diff_1 = CNTSimFile('../sim_output/2020-10-08-exciton_sim-kenr_kbnr_diff_prist_11.h5', kin_const_1)

# %%
exc_sim_kenr_kbnr_diff_1.parameter_dependence(100000, exciton_sim, constants_array, ['k_bnr', 'k_enr'],
                                   ['k_br', 'k_er', 'k_bnr', 'k_enr', 'k_be', 'k_ed', 'k_de', 'k_dnr'],
                                    diff_const, (1.07e15, 1.07e15/3),
                                   {'t_step': 1, 'r_exc_nm': 2, 'n_defects': 0, 'CNT_length': 750})
exc_sim_kenr_kbnr_diff_1.save()
# Out:
# Start of calculation: 2020-10-08 10:58:53.348754
# Start of exiton simulation: 2020-10-08 10:58:53.349315
# End exiton simulation: 2020-10-08 11:00:36.559058
# Elapsed time: 00:01:43
# rate constant set processed(1/ 10)
# Start of exiton simulation: 2020-10-08 11:00:36.564611
# End exiton simulation: 2020-10-08 11:02:45.861096
# Elapsed time: 00:02:09
# rate constant set processed(2/ 10)
# Start of exiton simulation: 2020-10-08 11:02:45.862957
# End exiton simulation: 2020-10-08 11:04:44.565979
# Elapsed time: 00:01:58
# rate constant set processed(3/ 10)
# Start of exiton simulation: 2020-10-08 11:04:44.575181
# End exiton simulation: 2020-10-08 11:06:36.570031
# Elapsed time: 00:01:51
# rate constant set processed(4/ 10)
# Start of exiton simulation: 2020-10-08 11:06:36.572168
# End exiton simulation: 2020-10-08 11:08:26.155998
# Elapsed time: 00:01:49
# rate constant set processed(5/ 10)
# Start of exiton simulation: 2020-10-08 11:08:26.158244
# End exiton simulation: 2020-10-08 11:10:07.074736
# Elapsed time: 00:01:40
# rate constant set processed(6/ 10)
# Start of exiton simulation: 2020-10-08 11:10:07.080711
# End exiton simulation: 2020-10-08 11:11:46.235737
# Elapsed time: 00:01:39
# rate constant set processed(7/ 10)
# Start of exiton simulation: 2020-10-08 11:11:46.241432
# End exiton simulation: 2020-10-08 11:13:23.821270
# Elapsed time: 00:01:37
# rate constant set processed(8/ 10)
# Start of exiton simulation: 2020-10-08 11:13:23.827401
# End exiton simulation: 2020-10-08 11:14:55.446075
# Elapsed time: 00:01:31
# rate constant set processed(9/ 10)
# Start of exiton simulation: 2020-10-08 11:14:55.452767
# End exiton simulation: 2020-10-08 11:16:25.920492
# Elapsed time: 00:01:30
# rate constant set processed(10/ 10)
# Start of exiton simulation: 2020-10-08 11:16:25.925578
# End exiton simulation: 2020-10-08 11:17:54.391805
# Elapsed time: 00:01:28
# End exiton simulation: 2020-10-08 11:17:54.394175
# Elapsed time: 00:19:01
